# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasreemaniga/DATA_690/blob/main/assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 6. Upload the 2017-2018 school year file "MERGED2017_18_PP.csv" to Colab/Deepnote or any Cloud environment of your choice (you can use your local environment too) and create a Jupyter notebook to explore the dataset:
#
# *   how many colleges or rows?
# *   how many variables or columns?
# *   Look at the first 5 colleges
# *   look at the last 5 colleges
# *   Look at a random sample of 5 colleges

# %%
import pandas as pd

# %%
yr17 = pd.read_csv('MERGED2017_18_PP.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1729,1909,1910,1911,1912,1913) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
yr17.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  COUNT_WNE_MALE1_P8  \
# 0     AL       35762           NaN      NaN     NaN  ...                 NaN
# 1     AL  35294-0110           NaN      NaN     NaN  ...                 NaN
# 2     AL  36117-3553           NaN      NaN     NaN  ...                 NaN
# 3     AL       35899           NaN      NaN     NaN  ...                 NaN
# 4     AL  36104-0271           NaN      NaN     NaN  ...                 NaN
#
# ...

# %%
no_of_colleges = len(yr17)
no_of_colleges
# Out:
# 7112

# %%
no_of_variables = len(yr17.columns)
no_of_variables
# Out:
# 2989

# %%
yr17[['INSTNM']].head(5)
# Out:
#                                 INSTNM
# 0             Alabama A & M University
# 1  University of Alabama at Birmingham
# 2                   Amridge University
# 3  University of Alabama in Huntsville
# 4             Alabama State University

# %%
yr17[['INSTNM']].tail(5)
# Out:
#                                                  INSTNM
# 7107                   Arizona State University at Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...
# 7109           High Desert Medical College - Bakerfield
# 7110                                       BCI - Malden
# 7111               HCI College - Fort Lauderdale Campus

# %%
yr17[['INSTNM']].sample(5)
# Out:
#                                          INSTNM
# 4161       Ross Medical Education Center-Taylor
# 3277   National American University-Sioux Falls
# 4399                   Vatterott College-Joplin
# 1810             Rasmussen University-Minnesota
# 4631  Indian Capital Technology Center-Sallisaw

# %% [markdown]
# ## 7. Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
#
# *   UNITID
# *   INSTNM
# *   CITY
# *   STABBR
# *   ZIP
# *   ADM_RATE
# *   UGDS
# *   TUITIONFEE_IN
# *   MN_EARN_WNE_P10

# %%
yr17_new = yr17[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]

# %% [markdown]
# ## 9. Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook will know the meaning of these variables.

# %%
from IPython.display import Markdown as md

# %%
md('UNITID - Unit Id of the institution, is the unique identification number given to the institutions')
# Out:
# UNITID - Unit Id of the institution, is the unique identification number given to the institutions

# %%
md('INSTNM - Institution Name')
# Out:
# INSTNM - Institution Name

# %%
md('CITY - city of the institution')
# Out:
# CITY - city of the institution

# %%
md('STABBR - State at which the institution is located')
# Out:
# STABBR - State at which the institution is located

# %%
md('ZIP - Zip code')
# Out:
# ZIP - Zip code

# %%
md('ADM_RATE - Admission rate  ')
# Out:
# ADM_RATE - Admission rate

# %%
md('UGDS - No.of Undergraduate degree students enrolled')
# Out:
# UGDS - No.of Undergraduate degree students enrolled

# %%
md('TUITIONFEE_IN - In-state tution fee')
# Out:
# TUITIONFEE_IN - In-state tution fee

# %%
md('MN_EARN_WNE_P10 - mean earnings of the institutes undergrade students ')
# Out:
# MN_EARN_WNE_P10 - mean earnings of the institutes undergrade students

# %% [markdown]
# ## 10. Explore the smaller data frame
#
#
# *   Look at the first 10 colleges
# *   look at the last 10 colleges
#
# *   Look at a random sample of 10 colleges
# *   Find and display UMBC
#
#
# *   Find and display Loyola College Maryland
# *   Find and display Johns Hopskins
#
# *   Calculate the min, max, and average in-state tution of the above four institutions.

# %%
yr17_new.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %%
yr17_new.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %%
yr17_new.sample(10)
# Out:
#       UNITID                                             INSTNM          CITY  \
# 4143  366401                                Las Positas College     Livermore
# 1753  173416                    Dakota County Technical College     Rosemount
# 971   145691                                   Illinois College  Jacksonville
# 4872  440101                      Empire Beauty School-Kennesaw      Kennesaw
# 1323  157270          Sullivan College of Technology and Design    Louisville
# 733   136109              Paul Mitchell the School-Jacksonville  Jacksonville
# 5500  455433  The Chicago School of Professional Psychology ...       Anaheim
# 706   134529              Hollywood Institute of Beauty Careers     Hollywood
# 2054  183114                     River Valley Community College     Claremont
# 5144  446455                  Precision Manufacturing Institute     Meadville
#
#      STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# ...

# %%
df1 = yr17_new[yr17_new['INSTNM'].str.contains('University of Maryland-Baltimore County')]
df1
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %%
df2 = yr17_new[yr17_new['INSTNM'].str.contains('University of Maryland-College Park')]
df2
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %%
df3 = yr17_new[yr17_new['INSTNM'].str.contains('Loyola University Maryland')]
df3
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %%
df4 = yr17_new[yr17_new['INSTNM'].str.contains('Johns Hopkins')]
df4
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %% [markdown]
# ### Calculate the min, max, and average in-state tution of the above four institutions.

# %%
Df = pd.concat([df1,df2,df3,df4], ignore_index = True)
Df
# Out:
#    UNITID                                   INSTNM          CITY STABBR  \
# 0  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1  163286      University of Maryland-College Park  College Park     MD
# 2  163046               Loyola University Maryland     Baltimore     MD
# 3  162928                 Johns Hopkins University     Baltimore     MD
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       21250    0.6021  11130.0        11518.0              NaN
# 1       20742    0.4450  29273.0        10399.0              NaN
# 2  21210-2699    0.7528   3903.0        47560.0              NaN
# 3  21218-2688    0.1254   5663.0        52170.0              NaN

# %%
Df[Df["TUITIONFEE_IN"] == Df["TUITIONFEE_IN"].max()]
# Out:
#    UNITID                    INSTNM       CITY STABBR         ZIP  ADM_RATE  \
# 3  162928  Johns Hopkins University  Baltimore     MD  21218-2688    0.1254
#
#      UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 3  5663.0        52170.0              NaN

# %% [markdown]
# ### Johns Hopkins University has the highest tution fee

# %%
Df[Df["TUITIONFEE_IN"] == Df["TUITIONFEE_IN"].min()]
# Out:
#    UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1  163286  University of Maryland-College Park  College Park     MD  20742
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1     0.445  29273.0        10399.0              NaN

# %% [markdown]
# ### University of Maryland-College Park has the lowest in-state tution fee

# %%
Df["TUITIONFEE_IN"].mean()
# Out:
# 30411.75

# %% [markdown]
# ## 11. Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.

# %%
dict = {'city':["MD","VA","WA","DE","PA"]}

# %%
Df_md=yr17_new.loc[yr17_new['STABBR'] == "MD"]    # searching for colleges in maryland
Df_md
# Out:
#         UNITID                                  INSTNM          CITY STABBR  \
# 1446    161651     Aesthetics Institute of Cosmetology  Gaithersburg     MD
# 1447    161688            Allegany College of Maryland    Cumberland     MD
# 1448    161767          Anne Arundel Community College        Arnold     MD
# 1449    161776               Brightwood College-Towson        Towson     MD
# 1450    161800                     Award Beauty School    Hagerstown     MD
# ...        ...                                     ...           ...    ...
# 6800  16210401          Cecil College - Elkton Station        Elkton     MD
# 7004  43018401     Strayer University-Rockville Campus     Rockville     MD
# 7005  43018402  Strayer University-Anne Arundel Campus  Millersville     MD
# 7006  43018403   Strayer University-White Marsh Campus     Baltimore     MD
# 7007  43018404  Strayer University-Owings Mills Campus  Owings Mills     MD
#
# ...

# %%
Df_dc=yr17_new.loc[yr17_new['STABBR'] == "DC"]    # searching for colleges in maryland
Df_dc
# Out:
#         UNITID                                             INSTNM        CITY  \
# 643     131159                                American University  Washington
# 644     131283                 The Catholic University of America  Washington
# 645     131399             University of the District of Columbia  Washington
# 646     131405  Pontifical Faculty of the Immaculate Conceptio...  Washington
# 647     131450                               Gallaudet University  Washington
# 648     131469                       George Washington University  Washington
# 649     131496                              Georgetown University  Washington
# 650     131520                                  Howard University  Washington
# 651     131803            Strayer University-District of Columbia  Washington
# 652     131830             National Conservatory of Dramatic Arts  Washington
# 653     131876                      Trinity Washington University  Washington
# ...

# %%
Df_va=yr17_new.loc[yr17_new['STABBR'] == "VA"]    # searching for colleges in maryland
Df_va
# Out:
#         UNITID                                          INSTNM  \
# 3627    231280                Paul Mitchell the School-Roanoke
# 3628    231411                   Advanced Technology Institute
# 3629    231420                              Averett University
# 3630    231536                    Blue Ridge Community College
# 3631    231554                            Bluefield University
# ...        ...                                             ...
# 6969  24893411  ECPI University-Virginia Beach Health Sciences
# 6970  24893412                  ECPI University-Richmond South
# 6971  24893413                       ECPI University-Innsbrook
# 6972  24893414                   ECPI University-Richmond West
# 6973  24893415                       ECPI University - Roanoke
#
#                 CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 3627         Roanoke     VA       24015       NaN    84.0            NaN
# ...

# %%
Df_pa=yr17_new.loc[yr17_new['STABBR'] == "PA"]    # searching for colleges in maryland
Df_pa
# Out:
#         UNITID                                             INSTNM  \
# 2933    210474             Jolie Hair and Beauty Academy-Hazleton
# 2934    210492               Bryn Athyn College of the New Church
# 2935    210508                              Academy of Vocal Arts
# 2936    210571                                   Albright College
# 2937    210599                            All-State Career School
# ...        ...                                                ...
# 7023  44378405               Strayer University-Warrendale Campus
# 7024  44378406                Strayer University-Allentown Campus
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 2933      Hazleton     PA       18201       NaN    61.0            NaN
# ...

# %%
Df_de=yr17_new.loc[yr17_new['STABBR'] == "DE"]    # searching for colleges in maryland
Df_de
# Out:
#         UNITID                                             INSTNM        CITY  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...       Lewes
# 635     130873                          Dawn Career Institute LLC      Newark
# 636     130907         Delaware Technical Community College-Terry       Dover
# 637     130934                          Delaware State University       Dover
# 638     130943                             University of Delaware      Newark
# 639     130989                              Goldey-Beacom College  Wilmington
# 640     131061        Schilling-Douglas School of Hair Design LLC      Newark
# 641     131098                                     Wesley College       Dover
# 642     131113                              Wilmington University  New Castle
# 4729    432524                 Delaware College of Art and Design  Wilmington
# 4917    441362        Harris School of Business-Wilmington Campus  Wilmington
# ...

# %%
Df_fivestates = pd.concat([Df_de, Df_dc,Df_md,Df_pa,Df_va],ignore_index = True)
Df_fivestates
# Out:
#        UNITID                                             INSTNM  \
# 0      130837  Margaret H Rollins School of Nursing at Beebe ...
# 1      130873                          Dawn Career Institute LLC
# 2      130907         Delaware Technical Community College-Terry
# 3      130934                          Delaware State University
# 4      130943                             University of Delaware
# ..        ...                                                ...
# 684  24893411     ECPI University-Virginia Beach Health Sciences
# 685  24893412                     ECPI University-Richmond South
# 686  24893413                          ECPI University-Innsbrook
# 687  24893414                      ECPI University-Richmond West
# 688  24893415                          ECPI University - Roanoke
#
#                CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0             Lewes     DE       19958       NaN     59.0            NaN
# ...

# %%
Df_fivestates.to_csv('Five_States_Colleges.csv', index=False)
